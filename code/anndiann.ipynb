# %% [markdown]
# # DIANN report to Anndata

# %% [markdown]
# * Convert the DIANN report table to anndata objects
# * separate by PG, PR, GG intensities etc

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import anndata as ad
import warnings

# %%
# %load_ext autoreload
# %autoreload 2
import loader
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Hardcoded/testing path

# %%
fp_path = '/Users/eileen.wang/Desktop/diann/SampleData/FP/diann-output'

# %% [markdown]
# ## import report.tsv

# %%
def load_report(path, search_engine='fp', header_only=False):
    """
    Read in long-form precursors file
    If search_engine is 'fp', read report.tsv
    If search_engine is 'bps', read results.tsv
    """
    file_name = 'report'
    if search_engine == 'bps':
        file_name = 'results'
    else:
        raise ValueError("Unsupported search engine")
    
    if header_only:
    ### load header 
        df = pd.read_csv(f'{path}/{file_name}.tsv', sep='\t', nrows=0)
    else:
        df = pd.read_csv(f'{path}/{file_name}.tsv', sep='\t')
    return df

#TODO: Add functionality to load partial report by level
#TODO: Use header only to predetermine columns to load

# %%
test = loader.DiannLoader("diann_columns.yaml")

# %%
testdf = test.load_to_df(
        "/Users/eileen.wang/Desktop/diann/SampleData/FP/diann-output/report.tsv",
        level="protein"
    )
# Out:
# /Users/eileen.wang/Desktop/diann/code/loader.py:136: DtypeWarning: Columns (68,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, sep='\t')
# Loaded 1511257 rows with 13/13 columns for level 'protein'

# %%
proteindf = test.load_to_df(
        "/Users/eileen.wang/Desktop/diann/SampleData/FP/diann-output/report.tsv",
        level="protein"
    )
# Out:
# /Users/eileen.wang/Desktop/diann/code/loader.py:132: DtypeWarning: Columns (68,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, sep='\t')
# Loaded 1511257 rows with 16/16 columns for level 'protein'
# /Users/eileen.wang/Desktop/diann/code/loader.py:184: UserWarning: Non-unique values found during aggregation: []
#   warnings.warn(f"Non-unique values found during aggregation: {unique_vals}")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/fw/_hz2f4mj6pdc3ffplz4b82lc0000gq/T/ipykernel_77036/1297782492.py in <cell line: 1>()
# ----> 1 proteindf = test.load_to_df(
#       2         "/Users/eileen.wang/Desktop/diann/SampleData/FP/diann-output/report.tsv",
#       3         level="protein"
#       4     )
#
# ~/Desktop/diann/code/loader.py in load_to_df(self, filepath, level, sections, strict)
# ...

# %%
df = testdf.copy()

# %%
test.load_to_adata(
        "/Users/eileen.wang/Desktop/diann/SampleData/FP/diann-output/report.tsv",
        'precursor')
# Out:
# /Users/eileen.wang/Desktop/diann/code/loader.py:136: DtypeWarning: Columns (68,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, sep='\t')
# Loaded 1511257 rows with 50/50 columns for level 'precursor'
# /opt/anaconda3/envs/diann_report_venv/lib/python3.9/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 120613 × 15
#     obs: 'Protein.Group', 'Protein.Ids', 'Protein.Names', 'Genes', 'All Mapped Proteins', 'All Mapped Genes', 'Modified.Sequence', 'Stripped.Sequence', 'Precursor.Id', 'Precursor.Charge', 'Lib.Index'
#     var: 'Run'
# ...

# %%
test.load_to_adata(
        "/Users/eileen.wang/Desktop/diann/SampleData/FP/diann-output/report.tsv",
        'protein')
# Out:
# /Users/eileen.wang/Desktop/diann/code/loader.py:136: DtypeWarning: Columns (68,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, sep='\t')
# Loaded 1511257 rows with 13/13 columns for level 'protein'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/diann_report_venv/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3811         try:
# -> 3812             return self._engine.get_loc(casted_key)
#    3813         except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %% [markdown]
# ## end
